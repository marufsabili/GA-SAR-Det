# %%
# !nvidia-smi

# %%
# %cd "C:\Users\labte\Research Purposes\LSDD Ship\ultralytics-main"

# %%
# !pip install -e .

# %%
import ultralytics
from ultralytics import YOLO

print("Ultralytics module path:", ultralytics.__file__)

# %%
import os

os.chdir("C:/Users/labte/LSDD Ship/Dataset SSDD/SSDD.v1i.yolov12")

HOME = os.getcwd()
print(HOME)

# %%
from ultralytics import YOLO

model = YOLO(r"C:\Users\labte\LSDD Ship\ultralytics-main\ultralytics\cfg\models\GA-SAR-Det\yolocustom.yaml")

results = model.train(
    data=r"C:\Users\labte\Research Purposes\LSDD Ship\Dataset SSDD\SSDD.v1i.yolov12\data.yaml",
    epochs=300,
    batch=16,         
    imgsz=640,       
    workers=1,       
    device=0 ,
    lr0=0.001,

    project=r"C:\Users\labte\Research Purposes\LSDD Ship\output_train\GA-SAR-Det",  
    name="exp6"
)
